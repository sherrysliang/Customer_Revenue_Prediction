# %%
import pandas as pd
import os
import json
from pandas.io.json import json_normalize #package for flattening json in pandas df
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
# Out:
# //anaconda/lib/python3.5/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_9.4.1) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.

# %%
train_df_raw = pd.read_csv('../data/train.csv')
test_df_raw = pd.read_csv('../data/test.csv')

# %%
def load_df(csv_path='../data/train.csv', nrows=None):
    JSON_COLUMNS = ['device', 'geoNetwork', 'totals', 'trafficSource']

    df = pd.read_csv(csv_path, dtype={'fullVisitorId': 'str'}, nrows=nrows)

    for column in JSON_COLUMNS:
        df = df.join(pd.DataFrame(df.pop(column).apply(pd.io.json.loads).values.tolist(), index=df.index))
    return df

print(os.listdir("../data"))
# Out:
# ['test.csv', 'train.csv', 'sample_submission.csv']

# %%
train_df = load_df()
test_df = load_df(csv_path = '../data/test.csv')

# %%
train_df.head()
# Out:
#   channelGrouping      date        fullVisitorId  \
# 0  Organic Search  20160902  1131660440785968503
# 1  Organic Search  20160902   377306020877927890
# 2  Organic Search  20160902  3895546263509774583
# 3  Organic Search  20160902  4763447161404445595
# 4  Organic Search  20160902    27294437909732085
#
#                         sessionId  socialEngagementType     visitId  \
# 0  1131660440785968503_1472830385  Not Socially Engaged  1472830385
# 1   377306020877927890_1472880147  Not Socially Engaged  1472880147
# 2  3895546263509774583_1472865386  Not Socially Engaged  1472865386
# 3  4763447161404445595_1472881213  Not Socially Engaged  1472881213
# 4    27294437909732085_1472822600  Not Socially Engaged  1472822600
#
#    visitNumber  visitStartTime     browser                    browserSize  \
# 0            1      1472830385      Chrome  not available in demo dataset
# 1            1      1472880147     Firefox  not available in demo dataset
# ...

# %%
json_str = train_df_raw.ix[1]['device']

# %%
def CustomParser(data):
    import json
    j1 = json.loads(data)
    return j1
df = pd.read_csv('../data/train.csv', converters={'device':CustomParser, 'geoNetwork':CustomParser})

# %%
json_str = train_df_raw.ix[1]['totals']
json.loads(json_str)
# Out:
# {'bounces': '1',
#  'hits': '1',
#  'newVisits': '1',
#  'pageviews': '1',
#  'visits': '1'}

# %%
list(train_df_raw.columns.values)
# Out:
# ['channelGrouping',
#  'date',
#  'device',
#  'fullVisitorId',
#  'geoNetwork',
#  'sessionId',
#  'socialEngagementType',
#  'totals',
#  'trafficSource',
#  'visitId',
#  'visitNumber',
#  'visitStartTime']

# %%
train_df_raw.channelGrouping.unique()
# Out:
# array(['Organic Search', 'Referral', 'Paid Search', 'Affiliates', 'Direct',
#        'Display', 'Social', '(Other)'], dtype=object)

# %%
list_of_devices = train_df_raw.device.apply(json.loads)
# get all the keys for devices column
keys = list()
for device in list_of_devices:
    keys.extend(x for x in device.keys() if x not in keys)

# %%
keys
# Out:
# ['operatingSystem',
#  'mobileDeviceModel',
#  'screenResolution',
#  'operatingSystemVersion',
#  'mobileInputSelector',
#  'mobileDeviceMarketingName',
#  'browser',
#  'mobileDeviceBranding',
#  'screenColors',
#  'language',
#  'deviceCategory',
#  'mobileDeviceInfo',
#  'browserSize',
#  'flashVersion',
#  'isMobile',
#  'browserVersion']

# %%
# for device in list_of_devices:
#     if device['deviceCategory'] != "mobile":
#         print(device)
#         break
# Out:
# {'operatingSystem': 'Windows', 'mobileDeviceModel': 'not available in demo dataset', 'screenResolution': 'not available in demo dataset', 'operatingSystemVersion': 'not available in demo dataset', 'mobileInputSelector': 'not available in demo dataset', 'mobileDeviceMarketingName': 'not available in demo dataset', 'browser': 'Chrome', 'mobileDeviceBranding': 'not available in demo dataset', 'screenColors': 'not available in demo dataset', 'language': 'not available in demo dataset', 'deviceCategory': 'desktop', 'mobileDeviceInfo': 'not available in demo dataset', 'browserSize': 'not available in demo dataset', 'flashVersion': 'not available in demo dataset', 'isMobile': False, 'browserVersion': 'not available in demo dataset'}

# %%
tmp_device_df = pd.DataFrame(
    train_df_raw.device.apply(json.loads).tolist())[["browser","operatingSystem","deviceCategory","isMobile"]]

# %%
tmp_geo_df = pd.DataFrame(
    train_df_raw.geoNetwork.apply(json.loads).tolist())[["continent","subContinent","country","city"]]

# %%
tmp_source_df = pd.DataFrame(
    train_df_raw.trafficSource.apply(json.loads).tolist())[["keyword","medium" , "source"]]

# %%
train_df_raw.totals[0]
# Out:
# '{"visits": "1", "hits": "1", "pageviews": "1", "bounces": "1", "newVisits": "1"}'

# %%
train_df_raw["revenue"] = pd.DataFrame(train_df_raw.totals.apply(json.loads).tolist())[["transactionRevenue"]].astype(np.)

# %%
train_df_raw[train_df_raw['revenue'] is not ].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-556822bf8bee> in <module>()
# ----> 1 train_df_raw[train_df_raw['revenue'] is not NULL].head()
#
# NameError: name 'NULL' is not defined

# %%
list_of_totals = train_df_raw.totals.apply(json.loads)
# get all the keys for devices column
total_keys = list()
for metrics in list_of_totals:
    total_keys.extend(x for x in metrics.keys() if x not in total_keys)

# %%
total_keys
# Out:
# ['visits', 'hits', 'newVisits', 'bounces', 'pageviews', 'transactionRevenue']

# %%
train_df_raw.head(100)
# Out:
#    channelGrouping      date  \
# 0   Organic Search  20160902
# 1   Organic Search  20160902
# 2   Organic Search  20160902
# 3   Organic Search  20160902
# 4   Organic Search  20160902
# 5   Organic Search  20160902
# 6   Organic Search  20160902
# 7   Organic Search  20160902
# 8   Organic Search  20160902
# 9   Organic Search  20160902
# 10  Organic Search  20160902
# 11  Organic Search  20160902
# 12  Organic Search  20160902
# 13  Organic Search  20160902
# 14  Organic Search  20160902
# 15  Organic Search  20160902
# 16  Organic Search  20160902
# 17  Organic Search  20160902
# 18  Organic Search  20160902
# 19  Organic Search  20160902
# 20  Organic Search  20160902
# 21  Organic Search  20160902
# 22  Organic Search  20160902
# 23  Organic Search  20160902
# 24  Organic Search  20160902
# 25  Organic Search  20160902
# 26  Organic Search  20160902
# 27  Organic Search  20160902
# 28        Referral  20160902
# 29  Organic Search  20160902
# ..             ...       ...
# ...

# %%
train_df.head()
# Out:
#   channelGrouping      date        fullVisitorId  \
# 0  Organic Search  20160902  1131660440785968503
# 1  Organic Search  20160902   377306020877927890
# 2  Organic Search  20160902  3895546263509774583
# 3  Organic Search  20160902  4763447161404445595
# 4  Organic Search  20160902    27294437909732085
#
#                         sessionId  socialEngagementType     visitId  \
# 0  1131660440785968503_1472830385  Not Socially Engaged  1472830385
# 1   377306020877927890_1472880147  Not Socially Engaged  1472880147
# 2  3895546263509774583_1472865386  Not Socially Engaged  1472865386
# 3  4763447161404445595_1472881213  Not Socially Engaged  1472881213
# 4    27294437909732085_1472822600  Not Socially Engaged  1472822600
#
#    visitNumber  visitStartTime     browser                    browserSize  \
# 0            1      1472830385      Chrome  not available in demo dataset
# 1            1      1472880147     Firefox  not available in demo dataset
# ...

# %%
test_df.adwordsClickInfo[0]
# Out:
# {'criteriaParameters': 'not available in demo dataset'}

# %%
drop_columns = list()
dict_columns = list()
for item in train_df.columns:
    if str(type(train_df[item][0])) =="<class 'dict'>":
        dict_columns.append(item)
        continue
    if len(train_df[item].unique()) == 1:
        drop_columns.append(item)
        continue

# %%
print(len(drop_columns), len(dict_columns), len(train_df.columns))
# Out:
# 18 1 50

# %%
def add_date_features(df):
    df['date'] = df['date'].astype(str)
    df["date"] = df["date"].apply(lambda x : x[:4] + "-" + x[4:6] + "-" + x[6:])
    df["date"] = pd.to_datetime(df["date"])
    
    df["month"]   = df['date'].dt.month
    df["day"]     = df['date'].dt.day
    df["weekday"] = df['date'].dt.weekday
    return df

# %%
str(type(train_df[item][0])) =="<class 'dict'>"
# Out:
# True

# %%
train_df = add_date_features(train_df)
test_df = add_date_features(test_df)

# %%
test_df = add_date_features(test_df)

# %%
def normalize_numerical_columns(df, isTrain = True):
    df["hits"] = df["hits"].astype(float)
    df["hits"] = (df["hits"] - min(df["hits"])) / (max(df["hits"]) - min(df["hits"]))

    df["pageviews"] = df["pageviews"].astype(float)
    df["pageviews"] = (df["pageviews"] - min(df["pageviews"])) / (max(df["pageviews"]) - min(df["pageviews"]))
    
    if isTrain:
        df["transactionRevenue"] = df["transactionRevenue"].fillna(0.0)
    return df

# %%
train = normalize_numerical_columns(train_df)
test = normalize_numerical_columns(test_df, isTrain = False)

# %%
train.drop(drop_columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-ef10e41eaf81> in <module>()
# ----> 1 train.drop(drop_columns)
#
# //anaconda/lib/python3.5/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    1905         For more information see the :ref:`user guide <io.hdf5>`.
#    1906
# -> 1907         Parameters
#    1908         ----------
#    1909         path_or_buf : str or pandas.HDFStore
#
# //anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in drop(self, labels, errors)
#
# ValueError: labels ['socialEngagementType' 'browserSize' 'browserVersion' 'flashVersion'
#  'language' 'mobileDeviceBranding' 'mobileDeviceInfo'
#  'mobileDeviceMarketingName' 'mobileDeviceModel' 'mobileInputSelector'
#  'operatingSystemVersion' 'screenColors' 'screenResolution' 'cityId'
# ...

# %%
non_relevant = ["visitNumber", "date", "fullVisitorId", "sessionId", "visitId", "visitStartTime"]

# %%
train_df = train_df.drop(non_relevant,axis=1)
train_df = train_df.drop(drop_columns,axis=1)
train_df = train_df.drop(dict_columns,axis=1)
test_df = test_df.drop(non_relevant,axis=1)
test_df = test_df.drop(drop_columns,axis=1)
test_df = test_df.drop(dict_columns,axis=1)

# %%
train_df.columns
# Out:
# Index(['channelGrouping', 'browser', 'deviceCategory', 'isMobile',
#        'operatingSystem', 'city', 'continent', 'country', 'metro',
#        'networkDomain', 'region', 'subContinent', 'bounces', 'hits',
#        'newVisits', 'pageviews', 'transactionRevenue', 'adContent', 'campaign',
#        'campaignCode', 'isTrueDirect', 'keyword', 'medium', 'referralPath',
#        'source', 'month', 'day', 'weekday'],
#       dtype='object')

# %%
train["totals_transactionRevenue"] = np.log1p(train["totals_transactionRevenue"].astype(float))
train_x, valid_x, train_y, valid_y = train_test_split(train[features], train["totals_transactionRevenue"], test_size=0.25, random_state=20)
# Out:
#   channelGrouping     browser deviceCategory isMobile operatingSystem  \
# 0  Organic Search      Chrome        desktop    False         Windows
# 1  Organic Search     Firefox        desktop    False       Macintosh
# 2  Organic Search      Chrome        desktop    False         Windows
# 3  Organic Search  UC Browser        desktop    False           Linux
# 4  Organic Search      Chrome         mobile     True         Android
#
#                             city continent         country  \
# 0                          Izmir      Asia          Turkey
# 1  not available in demo dataset   Oceania       Australia
# 2                         Madrid    Europe           Spain
# 3  not available in demo dataset      Asia       Indonesia
# 4  not available in demo dataset    Europe  United Kingdom
#
#                            metro    networkDomain   ...     campaign  \
# 0                      (not set)     ttnet.com.tr   ...    (not set)
# ...

# %%
numerical_lst =['bounces', 'hits',
       'newVisits', 'pageviews', 'transactionRevenue']
categorical_columns = [c for c in train.columns if not c not in numerical_lst]
for c in categorical_columns:
    le = LabelEncoder()
    train_vals = list(train[c].values.astype(str))
    test_vals = list(test[c].values.astype(str))
    
    le.fit(train_vals + test_vals)
    
    train[c] = le.transform(train_vals)
    test[c] = le.transform(test_vals)

# %%
train["totals_transactionRevenue"] = np.log1p(train["totals_transactionRevenue"].astype(float))
train_x, valid_x, train_y, valid_y = train_test_split(train[features], train["totals_transactionRevenue"], test_size=0.25, random_state=20)
